# %%
import numpy as np
import os
from tensorflow.keras import models, layers
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.preprocessing import image
from tensorflow.keras.preprocessing.image import img_to_array
import tensorflow as tf
import matplotlib.pyplot as plt
from tensorflow.keras import backend as K
from tensorflow.compat.v1.train import AdamOptimizer
# Out:
# WARNING:tensorflow:From C:\Users\hp\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
INIT_LR = 1e-3
BATCH_SIZE = 32
EPOCHS = 50
IMAGE_SIZE = 227
default_image_size = tuple((IMAGE_SIZE, IMAGE_SIZE))
image_size = 0
data_dir = "../../PlantVillage"
CHANNELS = 3
AUTOTUNE = tf.data.AUTOTUNE

# %%
#funtion for spliting the dataset
def get_dataset_partitions_tf(ds, train_split=0.8, val_split=0.1, test_split=0.1, shuffle=True, shuffle_size=10000):
    assert (train_split + test_split + val_split) == 1
    
    ds_size = ds.cardinality().numpy()
    
    if shuffle:
        ds = ds.shuffle(shuffle_size, seed=12)
    
    train_size = int(train_split * ds_size)
    val_size = int(val_split * ds_size)
    
    train_ds = ds.take(train_size)    
    val_ds = ds.skip(train_size).take(val_size)
    test_ds = ds.skip(train_size).skip(val_size)
    
    return train_ds, val_ds, test_ds

# %%
dataset = tf.keras.preprocessing.image_dataset_from_directory(
    "PlantVillage",
    seed =123,
    shuffle = True,
    image_size = (IMAGE_SIZE, IMAGE_SIZE),
    batch_size = BATCH_SIZE
)

train_ds, val_ds, test_ds = get_dataset_partitions_tf(dataset)
# Out:
# Found 2152 files belonging to 3 classes.

# %%
class_names = dataset.class_names
n_classes = len(class_names)
print(n_classes, class_names)
# Out:
# 3 ['Potato___Early_blight', 'Potato___Late_blight', 'Potato___healthy']

# %%
plt.figure(figsize=(10, 10))
for images, labels in train_ds.take(1):
  for i in range(9):
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(images[i].numpy().astype("uint8"))
    plt.title(class_names[labels[i]])
    plt.axis("off")

# %%
for image_batch, labels_batch in train_ds:
  print(image_batch.shape)
  print(labels_batch.shape)
  break
# Out:
# (32, 227, 227, 3)
# (32,)

# %%
train_ds = train_ds.cache().shuffle(999).prefetch(buffer_size=AUTOTUNE)
val_ds = val_ds.cache().shuffle(999).prefetch(buffer_size=AUTOTUNE)
test_ds = test_ds.cache().shuffle(999).prefetch(buffer_size=AUTOTUNE)

# %%
resize_and_rescale = tf.keras.Sequential([
  layers.experimental.preprocessing.Resizing(IMAGE_SIZE, IMAGE_SIZE),
  layers.experimental.preprocessing.Rescaling(1./255), #to converet the tensors into numpys 
])
# Out:
# WARNING:tensorflow:From C:\Users\hp\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\backend.py:873: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.

# %%
data_augmentation = tf.keras.Sequential([
  layers.experimental.preprocessing.RandomFlip("horizontal_and_vertical"),
  layers.experimental.preprocessing.RandomRotation(0.2),
])

# %%
input_shape = (IMAGE_SIZE, IMAGE_SIZE, CHANNELS)
batch_input_shape = (BATCH_SIZE, IMAGE_SIZE, IMAGE_SIZE, CHANNELS)
chanDim = -1
if K.image_data_format() == "channels_first":
    input_shape = (CHANNELS, IMAGE_SIZE, IMAGE_SIZE)
    batch_input_shape = (BATCH_SIZE, CHANNELS, IMAGE_SIZE, IMAGE_SIZE)
    chanDim = 1

# %%
# Assuming input_shape is (227, 227, 3), adjust it based on your actual input shape
input_shape = (227, 227, 3)
#_classes = 3  # Number of classes
dropout_rate = 0.4  # Dropout rate

model = models.Sequential([
    # Input Layer
    layers.Input(shape=input_shape),

    # Preprocessing Layers
    resize_and_rescale,
    data_augmentation,

    # Convolutional Layer 1
    layers.Conv2D(32, kernel_size=(5, 5), activation='relu'),

    # Convolutional Layer 2
    layers.Conv2D(64, kernel_size=(5, 5)),
    layers.ReLU(),

    # Intermediate Pooling
    layers.MaxPooling2D(pool_size=(3, 3)),
    layers.ReLU(),

    # Convolutional Layer 3
    layers.Conv2D(64, kernel_size=(3, 3)),
    layers.ReLU(),

    # Convolutional Layer 4
    layers.Conv2D(64, kernel_size=(3, 3)),
    layers.ReLU(),

    # Dropout Layer
    layers.Dropout(rate=dropout_rate),
    layers.ReLU(),

    # Fully Connected Layer 1
    layers.Flatten(),
    layers.Dense(64, activation='relu'),

    # Fully Connected Layer 2 (Output Layer)
    layers.Dense(n_classes, activation='softmax')
])


model.build(input_shape=batch_input_shape)
# Out:
# WARNING:tensorflow:From C:\Users\hp\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\layers\pooling\max_pooling2d.py:161: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.

# %%
#model summary 
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  sequential (Sequential)     (None, 227, 227, 3)       0
#
#  sequential_1 (Sequential)   (None, 227, 227, 3)       0
#
#  conv2d (Conv2D)             (None, 223, 223, 32)      2432
#
#  conv2d_1 (Conv2D)           (None, 219, 219, 64)      51264
#
#  re_lu (ReLU)                (None, 219, 219, 64)      0
#
#  max_pooling2d (MaxPooling2  (None, 73, 73, 64)        0
#  D)
#
#  re_lu_1 (ReLU)              (None, 73, 73, 64)        0
#
#  conv2d_2 (Conv2D)           (None, 71, 71, 64)        36928
#
#  re_lu_2 (ReLU)              (None, 71, 71, 64)        0
#
#  conv2d_3 (Conv2D)           (None, 69, 69, 64)        36928
#
#  re_lu_3 (ReLU)              (None, 69, 69, 64)        0
#
#  dropout (Dropout)           (None, 69, 69, 64)        0
#
#  re_lu_4 (ReLU)              (None, 69, 69, 64)        0
#
#  flatten (Flatten)           (None, 304704)            0
#
#  dense (Dense)               (None, 64)                19501120
#
#  dense_1 (Dense)             (None, 3)                 195
#
# =================================================================
# Total params: 19628867 (74.88 MB)
# Trainable params: 19628867 (74.88 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
model.compile(
    optimizer=tf.keras.optimizers.Adam(),
    loss=tf.keras.losses.SparseCategoricalCrossentropy(),
    metrics=['accuracy']
)

# %%
#traing 
history = model.fit(
    train_ds,
    batch_size=BATCH_SIZE,
    validation_data=val_ds,
    verbose=1,
    epochs=EPOCHS,
)
# Out:
# Epoch 1/50
# WARNING:tensorflow:From C:\Users\hp\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# WARNING:tensorflow:From C:\Users\hp\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\engine\base_layer_utils.py:384: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# 54/54 [==============================] - 182s 3s/step - loss: 0.9764 - accuracy: 0.4695 - val_loss: 0.7490 - val_accuracy: 0.4635
# Epoch 2/50
# 54/54 [==============================] - 162s 3s/step - loss: 0.6930 - accuracy: 0.7212 - val_loss: 0.5571 - val_accuracy: 0.7604
# Epoch 3/50
# 54/54 [==============================] - 183s 3s/step - loss: 0.5063 - accuracy: 0.8046 - val_loss: 0.7203 - val_accuracy: 0.7500
# Epoch 4/50
# 54/54 [==============================] - 212s 4s/step - loss: 0.4765 - accuracy: 0.8369 - val_loss: 0.9746 - val_accuracy: 0.6823
# Epoch 5/50
# 54/54 [==============================] - 200s 4s/step - loss: 0.4930 - accuracy: 0.8204 - val_loss: 0.4889 - val_accuracy: 0.8594
# Epoch 6/50
# 54/54 [==============================] - 206s 4s/step - loss: 0.3911 - accuracy: 0.8533 - val_loss: 0.3045 - val_accuracy: 0.9010
# Epoch 7/50
# 54/54 [==============================] - 199s 4s/step - loss: 0.3673 - accuracy: 0.8580 - val_loss: 0.4362 - val_accuracy: 0.7969
# Epoch 8/50
# 54/54 [==============================] - 171s 3s/step - loss: 0.4093 - accuracy: 0.8504 - val_loss: 0.2712 - val_accuracy: 0.8906
# Epoch 9/50
# 54/54 [==============================] - 160s 3s/step - loss: 0.2963 - accuracy: 0.8885 - val_loss: 0.2498 - val_accuracy: 0.9062
# Epoch 10/50
# 54/54 [==============================] - 161s 3s/step - loss: 0.2007 - accuracy: 0.9302 - val_loss: 0.2869 - val_accuracy: 0.8698
# Epoch 11/50
# 54/54 [==============================] - 163s 3s/step - loss: 0.2641 - accuracy: 0.8914 - val_loss: 0.2863 - val_accuracy: 0.9115
# Epoch 12/50
# 54/54 [==============================] - 157s 3s/step - loss: 0.2052 - accuracy: 0.9249 - val_loss: 0.3348 - val_accuracy: 0.8906
# Epoch 13/50
# 54/54 [==============================] - 167s 3s/step - loss: 0.1602 - accuracy: 0.9384 - val_loss: 0.1973 - val_accuracy: 0.9271
# Epoch 14/50
# 54/54 [==============================] - 163s 3s/step - loss: 0.1795 - accuracy: 0.9343 - val_loss: 0.0966 - val_accuracy: 0.9583
# Epoch 15/50
# 54/54 [==============================] - 163s 3s/step - loss: 0.1447 - accuracy: 0.9495 - val_loss: 0.0552 - val_accuracy: 0.9896
# Epoch 16/50
# 54/54 [==============================] - 158s 3s/step - loss: 0.1677 - accuracy: 0.9343 - val_loss: 0.1614 - val_accuracy: 0.9479
# Epoch 17/50
# 54/54 [==============================] - 164s 3s/step - loss: 0.1356 - accuracy: 0.9495 - val_loss: 0.0651 - val_accuracy: 0.9792
# Epoch 18/50
# 54/54 [==============================] - 167s 3s/step - loss: 0.1575 - accuracy: 0.9484 - val_loss: 0.2236 - val_accuracy: 0.8906
# Epoch 19/50
# 54/54 [==============================] - 164s 3s/step - loss: 0.1353 - accuracy: 0.9448 - val_loss: 0.0917 - val_accuracy: 0.9688
# Epoch 20/50
# 54/54 [==============================] - 164s 3s/step - loss: 0.0977 - accuracy: 0.9642 - val_loss: 0.1135 - val_accuracy: 0.9531
# Epoch 21/50
# 54/54 [==============================] - 169s 3s/step - loss: 0.0788 - accuracy: 0.9707 - val_loss: 0.0643 - val_accuracy: 0.9740
# Epoch 22/50
# 54/54 [==============================] - 164s 3s/step - loss: 0.1202 - accuracy: 0.9525 - val_loss: 0.2606 - val_accuracy: 0.9062
# Epoch 23/50
# 54/54 [==============================] - 160s 3s/step - loss: 0.0991 - accuracy: 0.9665 - val_loss: 0.1314 - val_accuracy: 0.9427
# Epoch 24/50
# 54/54 [==============================] - 165s 3s/step - loss: 0.0661 - accuracy: 0.9736 - val_loss: 0.0842 - val_accuracy: 0.9896
# Epoch 25/50
# 54/54 [==============================] - 167s 3s/step - loss: 0.1093 - accuracy: 0.9689 - val_loss: 0.3199 - val_accuracy: 0.8698
# Epoch 26/50
# 54/54 [==============================] - 161s 3s/step - loss: 0.0928 - accuracy: 0.9619 - val_loss: 0.1103 - val_accuracy: 0.9583
# Epoch 27/50
# 54/54 [==============================] - 161s 3s/step - loss: 0.1089 - accuracy: 0.9572 - val_loss: 0.0584 - val_accuracy: 0.9896
# Epoch 28/50
# 54/54 [==============================] - 165s 3s/step - loss: 0.0616 - accuracy: 0.9777 - val_loss: 0.1165 - val_accuracy: 0.9531
# Epoch 29/50
# 54/54 [==============================] - 161s 3s/step - loss: 0.0874 - accuracy: 0.9665 - val_loss: 0.1003 - val_accuracy: 0.9688
# Epoch 30/50
# 54/54 [==============================] - 161s 3s/step - loss: 0.0722 - accuracy: 0.9730 - val_loss: 0.0647 - val_accuracy: 0.9792
# Epoch 31/50
# 54/54 [==============================] - 164s 3s/step - loss: 0.0739 - accuracy: 0.9742 - val_loss: 0.0757 - val_accuracy: 0.9688
# Epoch 32/50
# 54/54 [==============================] - 170s 3s/step - loss: 0.0665 - accuracy: 0.9765 - val_loss: 0.0731 - val_accuracy: 0.9792
# Epoch 33/50
# 54/54 [==============================] - 160s 3s/step - loss: 0.0749 - accuracy: 0.9742 - val_loss: 0.3530 - val_accuracy: 0.9010
# Epoch 34/50
# 54/54 [==============================] - 162s 3s/step - loss: 0.1018 - accuracy: 0.9601 - val_loss: 0.0631 - val_accuracy: 0.9688
# Epoch 35/50
# 54/54 [==============================] - 162s 3s/step - loss: 0.0716 - accuracy: 0.9736 - val_loss: 0.0625 - val_accuracy: 0.9896
# Epoch 36/50
# 54/54 [==============================] - 155s 3s/step - loss: 0.0773 - accuracy: 0.9683 - val_loss: 0.0672 - val_accuracy: 0.9792
# Epoch 37/50
# 54/54 [==============================] - 160s 3s/step - loss: 0.0877 - accuracy: 0.9654 - val_loss: 0.0510 - val_accuracy: 0.9792
# Epoch 38/50
# 54/54 [==============================] - 151s 3s/step - loss: 0.1393 - accuracy: 0.9454 - val_loss: 0.1072 - val_accuracy: 0.9635
# Epoch 39/50
# 54/54 [==============================] - 156s 3s/step - loss: 0.1056 - accuracy: 0.9619 - val_loss: 0.1161 - val_accuracy: 0.9688
# Epoch 40/50
# 54/54 [==============================] - 158s 3s/step - loss: 0.1051 - accuracy: 0.9560 - val_loss: 0.0471 - val_accuracy: 0.9896
# Epoch 41/50
# 54/54 [==============================] - 165s 3s/step - loss: 0.0684 - accuracy: 0.9759 - val_loss: 0.0402 - val_accuracy: 0.9896
# Epoch 42/50
# 54/54 [==============================] - 166s 3s/step - loss: 0.0461 - accuracy: 0.9824 - val_loss: 0.0782 - val_accuracy: 0.9688
# Epoch 43/50
# 54/54 [==============================] - 158s 3s/step - loss: 0.0657 - accuracy: 0.9724 - val_loss: 0.1158 - val_accuracy: 0.9635
# Epoch 44/50
# 54/54 [==============================] - 166s 3s/step - loss: 0.0677 - accuracy: 0.9748 - val_loss: 0.0997 - val_accuracy: 0.9531
# Epoch 45/50
# 54/54 [==============================] - 179s 3s/step - loss: 0.0845 - accuracy: 0.9665 - val_loss: 0.0504 - val_accuracy: 0.9896
# Epoch 46/50
# 54/54 [==============================] - 187s 3s/step - loss: 0.0599 - accuracy: 0.9765 - val_loss: 0.1062 - val_accuracy: 0.9688
# Epoch 47/50
# 54/54 [==============================] - 186s 3s/step - loss: 0.0618 - accuracy: 0.9765 - val_loss: 0.0747 - val_accuracy: 0.9792
# Epoch 48/50
# 54/54 [==============================] - 166s 3s/step - loss: 0.0831 - accuracy: 0.9683 - val_loss: 0.2120 - val_accuracy: 0.9115
# Epoch 49/50
# 54/54 [==============================] - 172s 3s/step - loss: 0.0841 - accuracy: 0.9660 - val_loss: 0.0491 - val_accuracy: 0.9844
# Epoch 50/50
# 54/54 [==============================] - 170s 3s/step - loss: 0.0783 - accuracy: 0.9759 - val_loss: 0.2501 - val_accuracy: 0.9375

# %%
#testing
print("[INFO] Calculating model accuracy")
scores = model.evaluate(test_ds)
# Out:
# [INFO] Calculating model accuracy
# 8/8 [==============================] - 9s 862ms/step - loss: 0.2090 - accuracy: 0.9297

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(EPOCHS)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 2)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 1)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %%
for image_batch, label_batch in test_ds.take(1):
    first_image = image_batch[0].numpy().astype('uint8')
    first_label = label_batch[0].numpy()
    print("First image to predict")
    plt.imshow(first_image)
    print("actual label", class_names[first_label])

    batch_prediction = model.predict(image_batch)
    print("predicted label", class_names[np.argmax(batch_prediction[0])])
# Out:
# First image to predict
# actual label Potato___healthy
# 1/1 [==============================] - 1s 1s/step
# predicted label Potato___healthy

# %%
import os
import glob
from tensorflow import keras

os.makedirs("../saved_models", exist_ok=True)

existing_models = glob.glob("../saved_models/*")
model_version = max([int(os.path.basename(i)) for i in existing_models] + [0]) + 1

model_path = os.path.join("../saved_models", str(model_version))

# Create a Keras optimizer (e.g., Adam)
optimizer = keras.optimizers.Adam()

# Compile the model with the Keras optimizer
model.compile(optimizer=optimizer, loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# Save the model
model.save(model_path, save_format='tf')  # or 'h5' depending on your preference
# Out:
# INFO:tensorflow:Assets written to: ../saved_models\3\assets
# INFO:tensorflow:Assets written to: ../saved_models\3\assets

# %%
def predict(model, img):
    img_array = tf.keras.preprocessing.image.img_to_array(images[i].numpy())
    img_array = tf.expand_dims(img_array, 0) # Create a batch

    predictions = model.predict(img_array)

    predicted_class = class_names[np.argmax(predictions[0])]
    confidence = round(100 * (np.max(predictions[0])), 2)
    return predicted_class, confidence

# %%
plt.figure(figsize=(10, 12))
for images, labels in test_ds.take(1):
    for i in range(9):
        ax = plt.subplot(3, 3, i + 1)
        plt.imshow(images[i].numpy().astype("uint8"))
        predicted_class, confidence = predict(model, images[i].numpy())
        
        actual_class = class_names[labels[i]] 
        plt.title(f"Actual: {actual_class},\n Predicted: {predicted_class}.\n Confidence: {confidence}%")
        plt.axis("off")
# Out:
# 1/1 [==============================] - 0s 62ms/step
# 1/1 [==============================] - 0s 53ms/step
# 1/1 [==============================] - 0s 55ms/step
# 1/1 [==============================] - 0s 57ms/step
# 1/1 [==============================] - 0s 60ms/step
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 61ms/step
# 1/1 [==============================] - 0s 58ms/step
# 1/1 [==============================] - 0s 60ms/step
